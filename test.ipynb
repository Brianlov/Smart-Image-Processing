# %% [markdown]
# # Smart Image Processing Demo
# This notebook demonstrates how to use the `test.py` utilities to process a document image.
# Replace `sample.jpg` with your document image path and run the cell below.

# %%
from test import process_demo
import os

# Path to your document image (update before running)
image_path = 'sample.jpg'  # <-- change this to your image file
out_dir = 'outputs'

if not os.path.exists(image_path):
    print(f'Image not found: {image_path}. Please update the path and re-run.')
else:
    process_demo(image_path, out_dir)
    print('Processing complete. Outputs saved to', out_dir)
